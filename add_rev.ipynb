# %%
cases = input()

for lol in range(cases):
    
    a,b = raw_input().split()
    a = int(a)
    b = int(b)
    #print(a,b)
    revs = []
    revs.append(a)
    revs.append(b)
    revd = []
    #print (revs)
    for i in range(2):
        h = revs[i]
        q = h/10
        counter = 1
        while(q != 0):
            counter = counter + 1
            q = q/10
        dig = counter
        #print(dig)
        t = 0
        quo = h
        while (quo > 0):
            quo= h/10
            rem = h%10
            h = quo
            t = t+ rem*(10**(dig-1))
            dig = dig - 1
        #print(t)
        revd.append(t)
    #print(revd)
    sum = revd[0] + revd [1]
    #print(sum)
    h = sum
    q = h/10
    counter = 1
    while(q != 0):
        counter = counter + 1
        q = q/10
    dig = counter
    t = 0
    quo = h
    while (quo > 0):
        quo= h/10
        rem = h%10
        h = quo
        t = t+ rem*(10**(dig-1))
        dig = dig - 1
    print(t)
# Out:
# 3

# %%
n = input()
q = n/10
counter = 1
while(q != 0):
    print("enters")
    counter = counter + 1
    q = q/10
print(counter)
# Out:
# 96876
# enters
# enters
# enters
# enters
# enters
# enters
# enters
# enters
# enters
# enters
# enters
# enters
# enters
# enters
# enters
# enters
# enters
# enters
# enters
# enters
# enters
# enters
# enters
# enters
# enters
# enters
# enters
# enters
# enters
# enters
# enters
# enters
# enters
# enters
# enters
# enters
# enters
# enters
# enters
# enters
# enters
# enters
# enters
# enters
# enters
# enters
# enters
# enters
# enters
# enters
# enters
# enters
# enters
# enters
# enters
# enters
# enters
# enters
# enters
# enters
# enters
# enters
# enters
# enters
# enters
# enters
# enters
# enters
# enters
# enters
# enters
# enters
# enters
# enters
# enters
# enters
# enters
# enters
# enters
# enters
# enters
# enters
# enters
# enters
# enters
# enters
# enters
# enters
# enters
# enters
# enters
# enters
# enters
# enters
# enters
# enters
# enters
# enters
# enters
# enters
# enters
# enters
# enters
# enters
# enters
# enters
# enters
# enters
# enters
# enters
# ...

# %%
n = input()
q = n/10
counter = 1
while(q not in [-1,0]):
    counter = counter + 1
    q = q/10
print(counter)
# Out:
# 00
# 1
